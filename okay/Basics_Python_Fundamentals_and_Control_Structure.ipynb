# %%
print("HI")
# Out:
# HI

# %%
tiffin="Lunch"
print(tiffin)
# Out:
# Lunch

# %%
Drug="semaglutide"
print(Drug)
type(Drug)
# Out:
# semaglutide
# str

# %%
dose_mg=500.25
print(dose_mg)
type(dose_mg)
# Out:
# 500.25
# float

# %%
Quantity=100
type(Quantity)
# Out:
# int

# %%
TestCase=True
type(TestCase)
# Out:
# bool

# %% [markdown]
# Arithmetic OPerator

# %%
price=500
tax=1000
total=price+tax
print(total)
# Out:
# 1500

# %%
weight=70
Dose=5
total=weight*Dose
print(total)
safe_dose=300
print(total>safe_dose)
# Out:
# 350
# True

# %%
Pname=input("Enter patient Name=")
print(Pname)
age=int(input("Enter Patient Age ="))   # comment Type Casting =string->int
type(age)
# Out:
# Enter patient Name=Mogal
# Mogal
# Enter Patient Age =55
# int

# %%
CName="Pharmacy College"
print(len(CName))
CName[-3]  #indexing
# Out:
# 16
# 'e'

# %%
CName="Pharmacy College"
CName[9:12] #Slicing [start index:end index]
# Out:
# 'Col'

# %%
CName="Pharmacy College"
print(CName.upper())
print(CName.lower())
print(CName.title())
# Out:
# PHARMACY COLLEGE
# pharmacy college
# Pharmacy College

# %%
CName="Pharmacy,College,200mg,crocin"
print(CName.split(','))
# Out:
# ['Pharmacy', 'College', '200mg', 'crocin']

# %%
"para" in "paracetamol"
# Out:
# True

# %%
first="Suchita"  #concatenation
Last="Jadhav"
first + " " +  Last
# Out:
# 'Suchita Jadhav'

# %%
# if statement  Decision True
Patient_temp=39
if(Patient_temp>38): #39>38
  print("Fever")
else:
  print("Normal temp")
# Out:
# Fever

# %%
age=int(input("Enter age="))
if(age>18):   #true
  print("Adult")
else:
  print("Child")
# Out:
# Enter age=14
# Child

# %%
print("1")
print("2")
print("3")
print("4")
print("5")
print("6")
      #i
print("we are learning For loop ")
for i in range(1,7):  #start=0,stop,step=1
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# we are learning For loop
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(7): #start=0,stop=7,step=1
  print("Welcome all faculties",i)  # print text+ variable
# Out:
# Welcome all faculties 0
# Welcome all faculties 1
# Welcome all faculties 2
# Welcome all faculties 3
# Welcome all faculties 4
# Welcome all faculties 5
# Welcome all faculties 6
