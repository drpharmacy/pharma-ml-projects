# %% [markdown]
# # Organizing and Managing Pharmaceutical Data

# %% [markdown]
# ## Lists
# What is a List? \
# Creating Lists \
# Accessing Elements \
# Updating Elements \
# Adding Elements \
# Removing Elements \
# List Functions \
# Iterating through Lists

# %%
medicines = ["Paracetamol", "Crocin", "Dolo", "Aspirin"]
print(medicines)
# Out:
# ['Paracetamol', 'Crocin', 'Dolo', 'Aspirin']

# %%
patients = ["Rahul", "Anitha", "Ramesh"]
print(patients)
# Out:
# ['Rahul', 'Anitha', 'Ramesh']

# %%
num = [0, 1, 2, "zklksl", [2,3]]
print(num)
# Out:
# [0, 1, 2, 'zklksl', [2, 3]]

# %%
medicines = ["Paracetamol","Crocin","Dolo"]
print(medicines[0])
print(medicines[1])
print(medicines[2])
# Out:
# Paracetamol
# Crocin
# Dolo

# %%
medicines = ["Paracetamol","Crocin","Dolo"]
medicines[1]="PCM"
medicines[2]="ASD"

print(medicines)
# Out:
# ['Paracetamol', 'PCM', 'ASD']

# %%
medicines=[]
#medicines=list()
medicines.append("Paracetamol")
medicines.append("Crocin")
print(medicines)
# Out:
# ['Paracetamol', 'Crocin']

# %%
list()
# Out:
# []

# %%
medicines=["PCM","Crocin"]
medicines.insert(2,"Dolo")
print(medicines)
# Out:
# ['PCM', 'Crocin', 'Dolo']

# %%
medicines=["PCM","Crocin","Dolo"]
medicines.remove("Crocin")
print(medicines)
# Out:
# ['PCM', 'Dolo']

# %%
medicines=["PCM","Crocin","Dolo"]

medicines.pop()
print(medicines)

medicines.pop()
print(medicines)
# Out:
# ['PCM', 'Crocin']
# ['PCM']

# %%
medicines=["PCM","Crocin","Dolo"]

medicines.pop(0)
print(medicines)
# Out:
# ['Crocin', 'Dolo']

# %%
numbers=[10,30,20,50]
print(len(numbers))
print(max(numbers))
print(min(numbers))
numbers.sort()
print(numbers)
# Out:
# 4
# 50
# 10
# [10, 20, 30, 50]

# %%
numbers = [10,30,20,50]
for num in numbers:
    print(num)
# Out:
# 10
# 30
# 20
# 50

# %%
medicines=["PCM","Crocin","Dolo"]
for medicine in medicines:
    print(medicine)
# Out:
# PCM
# Crocin
# Dolo

# %%
medicines=["PCM","Crocin","Dolo"]
print("Crocin" in medicines)
print("Beplex" in medicines)
# Out:
# True
# False

# %% [markdown]
# ## Tuples
# Creating Tuples \
# Accessing Elements \
# Tuple Functions \
# Difference between List & Tuple

# %% [markdown]
# ## Dictionaries
# Creating Dictionary \
# Accessing Values \
# Updating Values \
# Adding Items \
# Removing Items \
# Dictionary Methods

# %% [markdown]
# ## Sets
# Creating Sets \
# Adding Elements \
# Removing Elements \
# Set Operations

# %% [markdown]
# ## File Handling
# Opening Files \
# Reading Files \
# Writing Files \
# Appending Files \
# Closing Files

# %% [markdown]
# ## CSV Handling

# %% [markdown]
# ## Exception Handling
# Why Exception Handling? \
# try \
# except \
# finally
