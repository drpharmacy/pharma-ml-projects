# %% [markdown]
# **Diabetes Diagnosis Using Supervised Machine Learning** or
# **Binary Classification of Diabetes Using Machine Learning** or
# **Prediction of Diabetes Using Logistic Regression Machine Learning Model**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load dataset directly from GitHub
url = "https://raw.githubusercontent.com/drpharmacy/pharma-ml-projects/main/diabetes.csv"
df = pd.read_csv(url)

# Display first 5 rows
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Select X and Y
X = df.drop(columns=["Outcome"])
y = df["Outcome"]

# %%
# Split the Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42
)

# %%
#Create the Logistic Regression Model
model = LogisticRegression(max_iter=1000)

# %%
#Train the Model
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#Predict
y_pred = model.predict(X_test)

# %%
#Compare Actual and Predicted Values
results = pd.DataFrame({
    "Actual": y_test,
    "Predicted": y_pred
})

results.head(10)
# Out:
#      Actual  Predicted
# 668       0          0
# 324       0          0
# 624       0          0
# 690       0          0
# 473       0          0
# 204       0          0
# 97        0          0
# 336       0          1
# 568       0          1
# 148       0          1

# %%
#Evaluate the Model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7467532467532467
#
# Confusion Matrix
# [[78 21]
#  [18 37]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80        99
#            1       0.64      0.67      0.65        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.73      0.73       154
# weighted avg       0.75      0.75      0.75       154

# %% [markdown]
# **Code Block 1: Import Libraries, Load Dataset and Display First Five Rows**
#
# Meaning:
#
# This code block imports the required Python libraries, loads the diabetes dataset from a CSV file into a Pandas DataFrame, and displays the first five records. This helps verify that the dataset has been imported correctly and allows us to understand its structure before developing the machine learning model.

# %% [markdown]
# **Code Block 2: Select X and Y**
# This code block separates the dataset into input features (X) and the target variable (Y). All patient health parameters such as glucose level, blood pressure, BMI, age, and insulin are stored in X, while the Outcome column, which indicates whether a patient has diabetes (1) or not (0), is stored in Y. The machine learning model uses X to learn the relationship between patient characteristics and Y so that it can predict whether a new patient is diabetic or non-diabetic.

# %% [markdown]
# **Code Block 3: Split the Dataset into Training and Testing Sets**
#
# Meaning:
#
# This code block divides the dataset into two parts: a training dataset and a testing dataset. The training dataset (80%) is used to teach the machine learning model, while the testing dataset (20%) is used to evaluate its performance on unseen data. This helps determine whether the model can make accurate predictions for new patients and prevents overfitting. The random_state=42 ensures that the data is split in the same way every time the program is executed, making the results reproducible.

# %% [markdown]
# **Code Block 4: Create the Logistic Regression Model**
#
# Meaning:
#
# This code block creates a Logistic Regression machine learning model, which is a supervised learning algorithm used for binary classification. In this practical, the model is designed to classify patients into one of two categories: Diabetic (1) or Non-Diabetic (0). The max_iter=1000 parameter specifies the maximum number of learning iterations, allowing the model sufficient time to identify the best mathematical relationship between the patient characteristics and the diabetes outcome.

# %% [markdown]
# **Code Block 5: Train the Model**
#
# Meaning:
#
# This code block trains the Logistic Regression model using the training dataset. During training, the model learns the relationship between the patient health parameters (input features) and the diabetes outcome (target variable). The knowledge gained during this step enables the model to classify new patients as diabetic or non-diabetic.
#
# **Code Block 6: Predict the Diabetes Outcome**
#
# Meaning:
#
# This code block uses the trained Logistic Regression model to predict the diabetes status of patients in the testing dataset. The predicted results are stored in y_pred and are later compared with the actual outcomes to evaluate the accuracy and performance of the machine learning model.

# %% [markdown]
# **Code Block 7: Compare Actual and Predicted Values**
#
# Meaning:
#
# This code block creates a table that displays the actual diabetes status and the predicted diabetes status for the first ten patients in the testing dataset. Comparing these values helps determine whether the Logistic Regression model has made correct predictions and provides a simple visual assessment of its performance before calculating evaluation metrics such as accuracy and the confusion matrix.

# %% [markdown]
# **Code Block 8: Evaluate the Model Performance**
#
# Meaning:
#
# This code block evaluates the performance of the Logistic Regression model by calculating the accuracy, generating a confusion matrix, and displaying a classification report. These evaluation metrics indicate how well the model classifies patients as diabetic or non-diabetic. They help assess the model's accuracy, identify correct and incorrect predictions, and measure important performance indicators such as precision, recall, and F1-score, thereby determining the reliability of the machine learning model.
